# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
import os
user = os.getenv('Francisca')
password = os.getenv('01121997')
connection_string = "postgresql://Francisca:01121997@localhost/SIG".format(user=user, password=password)
# %sql $connection_string
# Out:
# 'Connected: Francisca@SIG'

# %%
result = %sql SELECT concelho, mais_recente FROM confirmados_concelho WHERE mais_recente >500
# usando pandas
df = result.DataFrame()    
df.plot.pie(y='mais_recente', labels=df['concelho'])
# Out:
#  * postgresql://Francisca:***@localhost/SIG
# 11 rows affected.

# %%
df2 = result.DataFrame()
df2.plot.bar(x='concelho', y='mais_recente');
